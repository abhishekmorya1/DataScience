# %%
import pandas as pd

# %%
import random

# %%
# roll a single dice 

L=[]

for i in range(1000):
    a=random.randint(1,6)
    L.append(a)

# %%
len(L)
# Out:
# 1000

# %%
L[:5]
# Out:
# [2, 6, 1, 2, 5]

# %%
s = (pd.Series(L).value_counts()/pd.Series(L).value_counts().sum()).sort_index()

# %%
s
# Out:
# 1    0.150
# 2    0.170
# 3    0.188
# 4    0.177
# 5    0.163
# 6    0.152
# Name: count, dtype: float64

# %%
s.plot(kind="bar")
# Out:
# <Axes: >

# %%
# roll a two dice 

L=[]

for i in range(10000):
    a=random.randint(1,6)
    b=random.randint(1,6)
    L.append(a+b)

# %%
L[:10]
# Out:
# [7, 11, 6, 2, 6, 12, 8, 10, 10, 8]

# %%
s = (pd.Series(L).value_counts()/pd.Series(L).value_counts().sum()).sort_index()

# %%
s
# Out:
# 2     0.0269
# 3     0.0552
# 4     0.0793
# 5     0.1135
# 6     0.1357
# 7     0.1651
# 8     0.1393
# 9     0.1147
# 10    0.0849
# 11    0.0579
# 12    0.0275
# Name: count, dtype: float64

# %%
s.plot(kind="bar")
# Out:
# <Axes: >

# %%
import numpy as np

# %%
np.cumsum(s)
# Out:
# 2     0.0269
# 3     0.0821
# 4     0.1614
# 5     0.2749
# 6     0.4106
# 7     0.5757
# 8     0.7150
# 9     0.8297
# 10    0.9146
# 11    0.9725
# 12    1.0000
# Name: count, dtype: float64

# %%
np.cumsum(s).plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# # How to PDF(Probability Density Function) in Data Science

# %%
import seaborn as sns

# %%
iris  = pd.read_csv("iris.csv")

# %%
iris.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.kdeplot(data = iris, x="SepalLengthCm" , hue = "Species")


# KDE Plot (Kernel Density Estimate)
# Used to visualize the distribution of numerical data
# It creates a smooth curve instead of bars like a histogram.

# sns.kdeplot(
#     data=iris,              # DataFrame
#     x="SepalLengthCm",      # Numerical column for X-axis
#     hue="Species"           # Separate curves for each category
# )

# Syntax:
# sns.kdeplot(data=DATAFRAME, x="NUMERICAL_COLUMN", hue="CATEGORY_COLUMN")

# data  → Specifies the DataFrame
# x     → Specifies the numerical column to plot
# hue   → Separates the plot based on categories
#         (e.g., Setosa, Versicolor, Virginica)

# Example:
# sns.kdeplot(data=iris, x="SepalLengthCm", hue="Species")

# Higher curve → More data is concentrated around that value/range
# Lower curve  → Less data is concentrated around that value/range
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.kdeplot(data = iris, x="SepalWidthCm" , hue = "Species")
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Density'>

# %%
sns.kdeplot(data = iris, x="PetalLengthCm" , hue = "Species")
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %%
sns.kdeplot(data = iris, x="PetalWidthCm", hue = "Species")
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Density'>

# %%
train = pd.read_excel("train.xlsx")
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.kdeplot(data = train , x="Age" , hue="Survived")
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # How to use CDF

# %%
# KDE Plot
sns.kdeplot(data=iris, x="PetalWidthCm", hue="Species")

# ECDF Plot - CDF
sns.ecdfplot(data=iris, x="PetalWidthCm", hue="Species")
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Density'>

# %%
train["Age"].mean()
# Out:
# 29.69911764705882

# %%
train["Age"].std()
# Out:
# 14.526497332334042

# %%
sns.kdeplot(data = train , x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
x = (train['Age'] - train['Age'].mean())/train['Age'].std()

# %%
sns.kdeplot(x)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>
