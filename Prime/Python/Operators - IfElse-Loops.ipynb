# %% [markdown]
# # Operators - IfElse - Loops

# %%
# Operators in Python are special symbols or keywords used to perform
# operations on variables and values.

# Operators in Python->

# Arithmetic Operators
# Relational Operators
# Logical Operators
# Bitwise Operators
# Assignment Operators
# Membership Operators

# %%
# Arithmetric Operators
print(5+6)

print(5-6)

print(5*6)

print(5/2)

print(5//2)

print(5%2)

print(5**2)


# | Operator | Description         | Example       |
# | -------- | ------------------- | ------------- |
# | `+`      | Addition            | `5 + 3 = 8`   |
# | `-`      | Subtraction         | `5 - 3 = 2`   |
# | `*`      | Multiplication      | `5 * 3 = 15`  |
# | `/`      | Division            | `5 / 2 = 2.5` |
# | `//`     | Floor Division      | `5 // 2 = 2`  |
# | `%`      | Modulus (Remainder) | `5 % 2 = 1`   |
# | `**`     | Exponentiation      | `2 ** 3 = 8`  |
# Out:
# 11
# -1
# 30
# 2.5
# 2
# 1
# 25

# %%
# Relational Operators
print(4>5)

print(4<5)

print(4>=4)

print(4<=4)

print(4==4)

print(4!=4)

# | Operator | Description              |
# | -------- | ------------------------ |
# | `==`     | Equal to                 |
# | `!=`     | Not equal to             |
# | `>`      | Greater than             |
# | `<`      | Less than                |
# | `>=`     | Greater than or equal to |
# | `<=`     | Less than or equal to    |
# Out:
# False
# True
# True
# True
# True
# False

# %%
# Logical Operators
print(1 and 0)

print(1 or 0)

print(not 1)


# | Operator | Description                                      |
# | -------- | ------------------------------------------------ |
# | `and`    | Returns `True` if both conditions are true       |
# | `or`     | Returns `True` if at least one condition is true |
# | `not`    | Reverses the result                              |
# Out:
# 0
# 1
# False

# %%
# Bitwise Operators

# bitwise and
print(2 & 3)

# bitwise or
print(2 | 3)

# bitwise xor
print(2 ^ 3)

print(~3)

print(4 >> 2)

print(5 << 2)

# | Operator | Description |    |
# | -------- | ----------- | -- |
# | `&`      | AND         |    |
# | `        | `           | OR |
# | `^`      | XOR         |    |
# | `~`      | NOT         |    |
# | `<<`     | Left Shift  |    |
# | `>>`     | Right Shift |    |
# Out:
# 2
# 3
# 1
# -4
# 1
# 20

# %%
# Assignment Operators

# = 
# a = 2

a = 2

# a = a % 2
a %= 2

# a++ ++a

print(a)


# | Operator | Example   | Equivalent To |
# | -------- | --------- | ------------- |
# | `=`      | `x = 5`   | Assign 5      |
# | `+=`     | `x += 3`  | `x = x + 3`   |
# | `-=`     | `x -= 3`  | `x = x - 3`   |
# | `*=`     | `x *= 3`  | `x = x * 3`   |
# | `/=`     | `x /= 3`  | `x = x / 3`   |
# | `//=`    | `x //= 3` | `x = x // 3`  |
# | `%=`     | `x %= 3`  | `x = x % 3`   |
# | `**=`    | `x **= 2` | `x = x ** 2`  |
# Out:
# 0

# %%
# Membership Operators

# in/not in

print('D' not in 'Delhi')

print(1 in [2,3,4,5,6])


# | Operator | Description          |
# | -------- | -------------------- |
# | `in`     | Value is present     |
# | `not in` | Value is not present |
# Out:
# False
# False

# %%
# Program - Find the sum of a 3 digit number entered by the user


# % 10 → "Take the last digit."
# // 10 → "Remove the last digit."


number = int(input("Enter the three digit number:"))

a = number%10

number  = number//10

b = number%10

number  = number//10

c = number%10

print(a+b+c)
# Out:
# Enter the three digit number: 123
# 6

# %% [markdown]
# # if-else in Python:

# %%
# login program and indentation
# email -> abhimorya8826@gmail.com
# password -> 1234

email = input("Enter the Email id:")
password = input("Enter the password")

if email == "abhimorya8826@gmail.com" and password == "1234":
  print("welcome!")

elif email != "abhimorya8826@gmail.com":
  print("Wrong Email!")

elif email == "abhimorya8826@gmail.com" and password != "1234":
  print("Wrong Password!")
  password = input("Enter password Again!")
  if password == '1234':
    print("Welcome, finally!")
  else:
    print("Again Wrong Password!")
else:
  print("Not Correct!")
# Out:
# Enter the Email id: 65656
# Enter the password 64656
# Wrong Email!

# %%
# min of 3 number

a = int(input('first num'))
b = int(input('second num'))
c = int(input('third num'))

if a<b and a<c:
  print('smallest is',a)
elif b<c:
  print('smallest is',b)
else:
  print('smallest is',c)
# Out:
# first num 4
# second num 5
# third num 5
# smallest is 4

# %%
# menu driven calculator
menu = input("""
Hi! how can I help you.
1. Enter 1 for pin change
2. Enter 2 for balance check
3. Enter 3 for withdrawl
4. Enter 4 for exit
""")

if menu == '1':
  print('pin change')
elif menu == '2':
  print('balance')
else:
  print('exit')
# Out:
# Hi! how can I help you.
# 1. Enter 1 for pin change
# 2. Enter 2 for balance check
# 3. Enter 3 for withdrawl
# 4. Enter 4 for exit
# exit
