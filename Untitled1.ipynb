# %%
import pymysql

# %%
conn = pymysql.connect(host="localhost", database="campusx", user="root", password = "Abhi@12345@@")
conn

# %%
cur = conn.cursor()

# %%
query = "select * from abhi" 
cur.execute(query) 

for i in cur:
    print(i)
# Out:
# (1, 'karan sharma', 'karansh0411@gmail.com', '123345')
# (2, 'karan rawat', 'karanrawat0411@gmail.com', '1234')

# %%
# how many entries you want to insert-2
# enter name 
# enter gmail 
# enter password

# %%
n = int(input("How many entries you want to insert: "))

for i in range(n):
    user_id = int(input("Enter user id: "))
    name = input("Enter name: ")
    email = input("Enter email: ")
    password = input("Enter password: ")

    query = "INSERT INTO abhi (user_id, name, email, password) VALUES (%s, %s, %s, %s)"
    cur.execute(query, (user_id, name, email, password))

conn.commit()

print("Data inserted successfully")
# Out:
# How many entries you want to insert:  1
# Enter user id:  3
# Enter name:  abhishek
# Enter email:  abhi@gmail.com
# Enter password:  123
# Data inserted successfully
