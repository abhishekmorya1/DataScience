# %% [markdown]
# # statistics

# %%
# it is the science of collecting , organizing and analyzing data

# %%
# data - facts or information

# %%
#  types

# descriptive stats
# inferential stats

# %%
#  types

# descriptive stats
# inferential stats

# %%
# descriptive stats

# measure of central tendcy
# mean , mode , medn

# measur of disprsn
# std dev , var

# cov , correlatn , multicollnrty
# percentile , quantile 

# box plot (five numbr summary)
# outlier

# data distribution
# normal distribution
# pmf , cdf

# %%
# infr stats

# hypothesis testing
# z - test
# t - test
# chi square test
# anova test

# %%
# data gathering 

# data preprocessing

# null values
# fillna() , ffill() , bfill()
# random sample imputation
# knn imputer

# outliers
# percentile , quartile
# box plot
# five number summary
# z score 

# feature selection
# correlation
# variance inflation factor - vif (mulitcollnrty)
# chi square test (cat vs cat)
# anova test   (num vs cat)
# pca
# random forest


# handling catagorcl values
# label encoder
# ordinal encoder
# one hot encoding
# dummy variables

# %%
# data scnce

# matrix (1-d , 2-d , 3-d)
# dot product

# linear algebra (line equation)

# differentiation

# probability

# maxima , minima

# %%
# descriptive

# %%
# desc -  it has a finite no of possible values that can not be divided into smaller parts
# can we measure data - no
# can we count data - yes



# cont - it is an infinite number of possible values within a time interval, the values can be divide into samaller prts 
# can we meas - yes 

# wind speed
# time taken by prject to complete
# time to wake up

# %%
import numpy as np
import pandas as pd

# %%
# mean / avg

# %%
x = [90, 94, 53, 68, 79, 94, 53, 65, 87, 90, 70, 69, 65, 89, 85, 53, 47, 61, 27, 80]

m = sum(x)/len(x)
m
# Out:
# 70.95

# %%
a = np.array(x)
a
# Out:
# array([90, 94, 53, 68, 79, 94, 53, 65, 87, 90, 70, 69, 65, 89, 85, 53, 47,
#        61, 27, 80])

# %%
np.mean(x)
# Out:
# 70.95

# %%
np.average(x)
# Out:
# 70.95

# %%
s = pd.Series(a)
s.mean()
# Out:
# 70.95

# %%
# median

# %%
x = [20,10,14,24,15,26,17,19,12] 
x
# Out:
# [20, 10, 14, 24, 15, 26, 17, 19, 12]

# %%
x.sort()

# %%
x
# Out:
# [10, 12, 14, 15, 17, 19, 20, 24, 26]

# %%
a = np.array(x)
a
# Out:
# array([10, 12, 14, 15, 17, 19, 20, 24, 26])

# %%
np.median(a)
# Out:
# 17.0

# %%
x = [20,10,14,24,15,26,17,19,12,21] 
x
# Out:
# [20, 10, 14, 24, 15, 26, 17, 19, 12, 21]

# %%
x.sort()
x
# Out:
# [10, 12, 14, 15, 17, 19, 20, 21, 24, 26]

# %%
a = np.array(x)
a
# Out:
# array([10, 12, 14, 15, 17, 19, 20, 21, 24, 26])

# %%
np.median(a)
# Out:
# 18.0

# %%
x = [10, 12, 14, 15, 16, 19, 20, 21, 24,28]
x.sort()
a = len(x)

if a%2!=0:
    m = a//2
    print(x[m])
else:
    m = a//2
    s = x[m] + x[m-1]
    print(s/2)
# Out:
# 17.5

# %%
a = np.array(x)
a
# Out:
# array([10, 12, 14, 15, 16, 19, 20, 21, 24, 28])

# %%
np.median(a)
# Out:
# 17.5

# %%
# mode - most frequent value

# %%
import pandas as pd

# %%
l = [2,3,3,4,5,5,5,6,8,8,8,8,10]
l
# Out:
# [2, 3, 3, 4, 5, 5, 5, 6, 8, 8, 8, 8, 10]

# %%
s = pd.Series(l)
s
# Out:
# 0      2
# 1      3
# 2      3
# 3      4
# 4      5
# 5      5
# 6      5
# 7      6
# 8      8
# 9      8
# 10     8
# 11     8
# 12    10
# dtype: int64

# %%
s.mode()
# Out:
# 0    8
# dtype: int64

# %%
l = [3,3,5,5,5,6,8,8]
d = {}

for i in l:
    d[i] = l.count(i)
d

for i , j in d.items():
    if j == max(d.values()):
        print(i,"----",j)
# Out:
# 5 ---- 3

# %%
d
# Out:
# {3: 2, 5: 3, 6: 1, 8: 2}

# %%
a = 8
b = 5

if a>b:
    print("a is grtr")
else:
    print("b is grtr")
# Out:
# a is grtr

# %%
# and , or

# %%
a = 10
b = 20

# %%
10>15 and b>7
# Out:
# False

# %%
10>15 or b>7
# Out:
# True

# %%
# measure of dispersion

# %%
import pandas as pd
import numpy as np

# %%
l = [2,3,3,4,5,6,7,9,11]
l
# Out:
# [2, 3, 3, 4, 5, 6, 7, 9, 11]

# %%
a =np.array(l)
a

# %%
df = pd.DataFrame(l)
df

# %%
np.var(a)

# %%
np.std(a)

# %%
df[0].var()

# %%
df.std()

# %%
np.mean(a)

# %%
m = df.mean()

# %%
m

# %%
df

# %%
x = 0
for i in df[0]:
    x = x + (i-m)**2
x

# %%
x/8

# %%
m

# %%
df.columns = ["x"]

# %%
df["x-m"] = 0

# %%
m

# %%
df

# %%
for i in df.index:
    df["x-m"][i] = df["x"][i] - m
df

# %%
df["x-ms"] = 0

# %%
df

# %%
for i in df.index:
    df["x-ms"][i] = (df["x-m"][i])**2
df

# %%
(df["x-ms"].sum()/9)**.5

# %% [markdown]
# # hypothesis testing

# %%
# a random sample of size 20 from a population gives sample mean of 42and sample std dev of 6
# test hypothesis that the population mean is 44

# alpha 5% -> 0.05

# %%
# h0 : u = 44
# ha : u != 44

# %%
n = 20
sm = 42
sstd = 6
pp = 44

# %%
tc = (42-44)/(6/20**.5)
tc

# %%
df = 19

# %%
tstats = 2.09

# %%
if tstats>tc:
    print("accpt null hypothesis")
else:
    print("reject null hypothesis")

# %%
# p - value

# %%
l = [183, 152, 178, 157, 194, 163, 144, 114, 178, 152, 118, 158, 172, 138]

# %%
pm = 165

# %%
import numpy as np

# %%
sm = np.array(l).mean()

# %%
sm

# %%
sd = np.array(l).std()
sd = 23.4
sd

# %%
n = 14

# %%
tc = (157-165)/(23.4/n**.5)
tc

# %%
tstats = 2.1

# %% [markdown]
# # t test

# %%
sys_bp=[183, 152, 178, 157, 194, 163, 144, 114, 178, 152, 118, 158, 172, 138]


mu=165


from scipy import stats

t_value,p_value=stats.ttest_1samp(sys_bp,mu)

one_tailed_p_value=float("{:.6f}".format(p_value/2)) # Since alternative hypothesis is one tailed, We need to divide the p value by 2.

print('Test statistic is %f'%float("{:.6f}".format(t_value)))

print('p-value for one tailed test is %f'%one_tailed_p_value)

alpha = 0.05

if one_tailed_p_value<=alpha:
  print('Conclusion','n','Since p value(=%f)'%p_value,'<','alpha(=%.2f)'%alpha,'''We reject the null hypothesis H0. So we conclude that there is no significant mean difference in systolic blood pressure. i.e., μ = 165 at %.2f level of significance'''%alpha)

else:
  print('Conclusion','n','Sincep-value(=%f)'%one_tailed_p_value, '>', 'alpha(=%.2f)'%alpha,'We do not reject the null hypothesis H0.')

# %%
p<alpha

# %%
a  b   c
2  3   4 
4  5   6
6  7   8

# %%
42000
p1 ,p2 ,p3 ,p4

# %%
10500 - p1
10500 - p2
10500 - p3
10500 - p4

# %%
p1  p2   p3  
2   3   4    
4   5   6    
6   7   8

# %%
import pandas as pd

# %%
df = pd.read_excel("case_study2.xlsx")
df.head()

# %%
p1 - 12000
p2 - 12000
p3 - 12000
p4 - 12000

# %%
x     aprv_flag

1       p1
2       p1
9       p1
4       p2
2       p2
5       p2
6       p1
7       p2
2       p2
8       p1

# %%
p2   p1
5    1
2    2
7    9
2    6
4    8

# %%
5.5  5.5

# %%
# data pre processing

# %%
# data gathering 

# data preprocessing

# null values
# fillna() , ffill() , bfill()
# random sample imputation
# knn imputer

# outliers
# percentile , quartile
# box plot
# five number summary
# z score 

# feature selection
# correlation
# variance inflation factor - vif (mulitcollnrty)
# chi square test (cat vs cat)
# anova test   (num vs cat)
# pca
# random forest


# handling catagorcl values
# label encoder
# ordinal encoder
# one hot encoding
# dummy variables

# %%
# how to reverse without slicing

# %%
s = "arun dabral"
