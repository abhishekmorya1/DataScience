# %%
# read mode - r
# write mode- w
# append mode- a

# %%
# read mode -

# %%
f = open("arun.txt" , "r")

f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 f = open("arun.txt" , "r")
#       2
#       3 f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'arun.txt'

# %%
f = open(r"C:\Users\user\Desktop\Data Set\file1.txt" , "r")

f.read()

# %%
f = open("ankit.txt" , "r")

print(f.read())

# %%
print(f.read())

# %%
f1 = open("ankit.txt" , "r")

f2 = open("arun.txt" , "r")


if f1.read() == f2.read():
    print("same contnt")
else:
    print("diff ")

# %%
f = open("arun.txt" , "r")

# %%
f.name

# %%
f.mode

# %%
f.readable()

# %%
f.writable()

# %%
f.closed

# %%
f.close()

# %%
f.closed

# %%
f = open("arun.txt" , "r")

x = f.read()

for i in x:
    print(i)

# %%
f = open("arun.txt" , "r")

x = f.readlines()

for i in x:
    print(i)

# %%
# no of lines - 3
# no of words - 8
# no of chrctr - 30

# %%
f = open("arun.txt" , "r")

x = f.readlines()

lc = 0
wc = 0
cc = 0

for i in x:
    cc = cc + len(i)
    lc = lc+1
    wc = wc + len(i.split())

lc
cc
wc

# %%
i = "how are you"
i

# %%
len(i)

# %%
len(i.split())

# %%
# write mode 

# if file dsnt exist thn it will create a new file
# if file alredy exist thn it will ovrwrite prvs data

# %%
f = open("tina.txt","w")

f.write("hello tina")

f.close()

# %%
f = open("arun.txt","w")

f.write("hello dear")

f.close()

# %%
# append

# purane data k bad new data add krta h

# %%
f = open("arun.txt","a")

f.write(" arun")

f.close()

# %%
f = open("arun.txt","a")

f.write("\n gdmg")

f.close()

# %%
# read data from file 1 and write that data in file 2
# reverse all lines

# %%
2  3   5
4  5   9
6  1   7
2  4   6
=========
 total 27

# %%
f1 = open(r"C:\Users\abbim\Desktop\DataScience\Python\File Handling\first.txt", "r")

f2 = open(r"C:\Users\abbim\Desktop\DataScience\Python\File Handling\second.txt" , "w")

x = f1.read()

f2.write(x)

f2.close()

# %%
f1 = open(r"C:\Users\abbim\Desktop\DataScience\Python\File Handling\first.txt", "r")

x = f1.readlines()
x
# Out:
# ['Hello Abhishek here\n',
#  'Hello karan this side \n',
#  'Hello krrish this side\n',
#  'Hello kuch nhi this side\n']

# %%
for i in x[::-1]:
    print(i)
# Out:
# Hello kuch nhi this side
#
# Hello krrish this side
#
# Hello karan this side
#
# Hello Abhishek here

# %%
f1 = open(r"C:\Users\abbim\Desktop\DataScience\Python\File Handling\first.txt", "r")

f2 = open(r"C:\Users\abbim\Desktop\DataScience\Python\File Handling\second.txt" , "w")

x = f1.readlines()

for i in x[::-1]:
    f2.write(i)

f2.close()

# %%
x
# Out:
# ['Hello Abhishek here\n',
#  'Hello karan this side \n',
#  'Hello krrish this side\n',
#  'Hello kuch nhi this side\n']

# %%
for i in x[::-1]:
    print(i)
# Out:
# Hello kuch nhi this side
#
# Hello krrish this side
#
# Hello karan this side
#
# Hello Abhishek here
