# %% [markdown]
# # list

# %%
x=[1,2,3,4,5]
x
# Out:
# [1, 2, 3, 4, 5]

# %%
type(x)
# Out:
# list

# %%
x1=[1,2,3.3,"abhishek", [1,2,"abhishek"]]
x1
# Out:
# [1, 2, 3.3, 'abhishek', [1, 2, 'abhishek']]

# %%
type(x1)
# Out:
# list
