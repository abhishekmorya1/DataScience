# %%
# String 
# any character within quotes (single, double, triple) act as string

# %%
s1= 'abhishek'
s2 = "abhishek"
s3 = '''abhishek'''
print(s1, type(s1))
print(s2, type(s2))
print(s3, type(s3))
# Out:
# abhishek <class 'str'>
# abhishek <class 'str'>
# abhishek <class 'str'>

# %%
# difference between single, double and triple quotes 

# | Quote Type | Best Use                                                              |
# | ---------- | --------------------------------------------------------------------- |
# | `' '`      | Simple strings                                                        |
# | `" "`      | Strings containing apostrophes (`I'm`, `don't`)                       |
# | `''' '''`  | Multi-line strings and docstrings                                     |
# | `""" """`  | Multi-line strings and docstrings (most commonly used for docstrings) |


# Use single quotes when your string contains double quotes.

s1 = 'python' 
print(s1)

text = 'She said "Hello"'
print(text)

# Use double quotes when your string contains single quotes (apostrophes).

s2 = "My name is Abhishek Morya"
print(s2)

text2 = "I'm learning Python."
print(text2)


#  triple string Used for multi-line strings and docstrings.

message = """Hello,
Welcome to Python.
Have a great day!"""

print(message)

# Docstring Example
def add(a, b):
    """Returns the sum of two numbers."""
    return a + b

print(add.__doc__)
# Out:
# python
# She said "Hello"
# My name is Abhishek Morya
# I'm learning Python.
# Hello,
# Welcome to Python.
# Have a great day!
# Returns the sum of two numbers.

# %%
# String supports Indexing

# String Indexing in Python
# String indexing means accessing individual characters of a string using their position (index).
# Python uses zero-based indexing, which means the first character starts at index 0.

text = "Python"

print(text[0])
print(text[1])
print(text[2])
print(text[5])

# Negative Indexing
# Negative indexing starts from the end of the string.

text1 = "Python"

print(text1[-1])
print(text1[-2])
print(text1[-6])


# Using len() with Indexing
# The len() function returns the number of characters in a string.

text3 = "Python"

print(len(text3))

# Index Out of Range
# If you try to access an index that doesn't exist, Python raises an error.

# text4 = "Python"

# print(text4[10])


# | Index Type      | Starts From   | Example                |
# | --------------- | ------------- | ---------------------- |
# | Positive Index  | Beginning     | `text[0]`, `text[2]`   |
# | Negative Index  | End           | `text[-1]`, `text[-2]` |
# | First Character | `0`           | `text[0]`              |
# | Last Character  | `-1`          | `text[-1]`             |
# | Invalid Index   | Outside range | `IndexError`           |

# Key Points

# Indexing is used to access individual characters in a string.
# Python uses 0-based indexing.
# Negative indexing accesses characters from the end.
# Strings are immutable, so you cannot modify characters using indexing.
# Out:
# P
# y
# t
# n
# n
# o
# P
# 6

# %%
# Slicing in Python

# String slicing is used to extract a portion (substring) of a string.

# string[start : stop : step]
# start → Starting index (included)
# stop → Ending index (excluded)
# step → Number of positions to move (optional)

# Remember: The stop index is not included in the output.

# Basic Slicing
text = "Python"

print(text[0:2])
print(text[2:5])
print(text[1:4])

# Omitting Start Index -> If start is omitted, Python starts from index 0
text = "Python"

print(text[:3])

# Omitting Stop Index -> If stop is omitted, python goes till the eIndentationError

print(text[1:])

# Omitting Both Start and Stop -> print the copy of the sBytesWarning

print(text[:])

# using step -> The step tells Python how many positions to skip.

print(text[::2])

# Reverse a string -> Use a negative step.
print(text[::-1])

# Negative Indexing -> Negative Index Slicing

text2 = "Python"

print(text2[-4:-1])
print(text2[0:11:2])



text3 = "Programming"

print(text3[:7])      # Program
print(text3[3:])      # gramming
print(text3[::3])     # Pgmn
print(text3[-5:])     # mming
print(text3[:-3])     # Programm
print(text3[::-1])    # gnimmargorP
# Out:
# Py
# tho
# yth
# Pyt
# ython
# Python
# Pto
# nohtyP
# tho
# Pto
# Program
# gramming
# Pgmn
# mming
# Programm
# gnimmargorP

# %%
# Common String Methods in Python

# Python provides many built-in methods to work with strings. Four of the most commonly used are:

# len() – Returns the length of the string.
# index() – Returns the position of a substring.
# count() – Counts how many times a substring appears.
# replace() – Replaces one substring with another.

text = "Python"

print(len(text)) 

text1 = "Hello World"

print(len(text1)) #space is also counted

# Index
# string.index(value, start, end)
# value → Substring to search for (required)
# start → Starting index (optional)
# end → Ending index (optional)
text2 = "Python"

print(text2.index("t"))

text3 = "Programming"

print(text3.index("g"))
print(text3.index("g", 4)) #using start


# Count Method ->The count() method returns the number of times a substring appears in the string.
# string.count(value, start, end)

text4 = "banana"

print(text4.count("a"))

text5 = "Python is easy. Python is powerful."

print(text5.count("Python"))

# Replace Method -> The replace() method replaces all occurrences of one substring with another.

# string.replace(old, new, count)
# old → Text to replace
# new → Replacement text
# count → Number of replacements (optional)

text6 = "Hello World"

print(text6.replace("World", "Python"))

text7 = "banana"

print(text7.replace("a", "o"))

text8 = "banana"

print(text8.replace("a", "o", 1))


text9 = "Programming"

print("Length :", len(text9))
print("Index of 'g' :", text9.index("g"))
print("Count of 'm' :", text9.count("m"))
print("Replace :", text9.replace("Programming", "Python"))
# Out:
# 6
# 11
# 2
# 3
# 10
# 3
# 2
# Hello Python
# bonono
# bonana
# Length : 11
# Index of 'g' : 3
# Count of 'm' : 2
# Replace : Python

# %%
#loop in String 

a="Abhishek" 
for i in a:
   print(i)


# find length using loop 

b="Python"
len = 0 

for i in b:
    len+=1
print("the length of string is: " , len)
# Out:
# A
# b
# h
# i
# s
# h
# e
# k
# the length of string is:  6

# %%
c= "ankita"
count=0

for i in c:
    if i=="a": 
        count+=1

print(count)
# Out:
# 2

# %%
# phone number
#  start with 9,8 and len=10

s = "9873393439"

if (s[0] == "9" or s[0] == "8") and len(s) == 10:
    print("Valid Number")
else:
    print("Invalid Number")
# Out:
# Valid Number

# %%
# common between two string

s1="abcd"
s2="kabm"

for i in s1:
    if i in s2:
        print(i)
# Out:
# a
# b

# %%
# upper() -> convert all string in uppercase 
# lower() -> convert all string in lowercase
# title() -> first letter of each  word in uppercase and rest in lowercaseabs
# swapcase()-> uppercase to lowercase and lowercase to uppercase 
# capitalize() -> convert only first letter of string in upper case and rest in lowercase 

s2 = "How pYthON easY LeArn"

# %%
s2.upper()
# Out:
# 'HOW PYTHON EASY LEARN'

# %%
s2.lower()
# Out:
# 'how python easy learn'

# %%
s2.title()
# Out:
# 'How Python Easy Learn'

# %%
s2.swapcase()
# Out:
# 'hOW PyTHon EASy lEaRN'

# %%
s2.capitalize()
# Out:
# 'How python easy learn'

# %%
# isupper()
# islower()
# istitle()
# isalpha() -> a-z , A-Z 
# isalnum() -> a-z A-Z 0-9 
# isdigit() -> 0-9
# isspace() -> if space is there then it gives true

# %%
s="ABHISHEK"
s.isupper()
# Out:
# True

# %%
s="abhishek"
s.islower()
# Out:
# True

# %%
s="My Name Is Abhishek Morya"
s.istitle()
# Out:
# True

# %%
s="abhishek"
s.isalpha()
# Out:
# True

# %%
s="python99" 
s.isalnum()
# Out:
# False

# %%
s="9898888998"
s.isdigit()

# %%
s="abhishek morya"
s.isspace()

# %%
# Find frequency of each character
s = "abchdshajabdjdiamkqwerutuiomnbvcxzasdfghjkloquehsdsm"

visited = ""

for ch in s:
    if ch not in visited:
        print(ch, ":", s.count(ch))
        visited = visited + ch
# Out:
# a : 5
# b : 3
# c : 2
# h : 4
# d : 5
# s : 4
# j : 3
# i : 2
# m : 3
# k : 2
# q : 2
# w : 1
# e : 2
# r : 1
# u : 3
# t : 1
# o : 2
# n : 1
# v : 1
# x : 1
# z : 1
# f : 1
# g : 1
# l : 1

# %%
# Remove duplicates in python
s = "abchdshajabdjdiamkqwerutuiomnbvcxzasdfghjkloquehsdsm"

new = ""

for ch in s:
    if ch not in new:
        new = new + ch

print(new)
# Out:
# abchdsjimkqwerutonvxzfgl

# %%
# Play with Empty String

s="abhishek"
s1=""
for i in s:
    s1=s1+i
    print(s1)
# Out:
# a
# ab
# abh
# abhi
# abhis
# abhish
# abhishe
# abhishek

# %%
# find only upper characters and also count them
s="AbHIShek"
s1=""
count=0
for ch in s:
    if ch.isupper():
        count=count+1
        s1=s1+ch
        
print("Upper Characters:",s1)
print("Count of Upper character is:",count)
# Out:
# Upper Characters: AHIS
# Count of Upper character is: 4

# %%
# find upper,lower,digit,special count
s="AbHIShek837@#$"
# s1=""
UpperCount=0
LowerCount=0
DigitCount=0
SpecialCount=0
for ch in s:
    if ch.isupper():
        UpperCount=UpperCount+1
        # s1=s1+ch
    elif ch.islower():
        LowerCount = LowerCount+1
    elif ch.isdigit():
        DigitCount = DigitCount+1
    else:
        SpecialCount=SpecialCount+1
        
print("Upper Characters:",UpperCount)
print("Lower Characters:",LowerCount)
print("Digit Characters:",DigitCount)
print("Special Characters:",SpecialCount)
# Out:
# Upper Characters: 4
# Lower Characters: 4
# Digit Characters: 3
# Special Characters: 3

# %%
# find upper,lower,digit,special characters

s="AbHIShek837@#$"
# s1=""

Upper_string=""
Lower_string=""
Digit_string=""
Special_string=""

for ch in s:
    if ch.isupper():
        Upper_string=Upper_string+ch
    elif ch.islower():
        Lower_string=Lower_string+ch
    elif ch.isdigit():
        Digit_string=Digit_string+ch
    else:
        Special_string=Special_string+ch
        
print("Upper Characters:",Upper_string)
print("Lower Characters:",Lower_string)
print("Digit Characters:",Digit_string)
print("Special Characters:",Special_string)
# Out:
# Upper Characters: AHIS
# Lower Characters: bhek
# Digit Characters: 837
# Special Characters: @#$

# %%
s="ab53cm7wd4"
sum=0

for ch in s:
    if ch.isdigit():
        sum=sum+int(ch)
print(sum)
# Out:
# 19

# %%
# reverse string using loop
s="abhishek"
s1=""

for ch in s:
    s1=ch+s1
print(s1)
# Out:
# kehsihba

# %%
# find vowel

s="abhishek"

for i in s:
    if i in "aeiou":
        print(i)
# Out:
# a
# i
# e

# %%
#count frequency of string

s="abhgsuoadkaldlhahdabkjncknskjciwhwjlkj"
s1=""

# for i in s:
#     if i not in s1:
#         s1=s1+i
# print(s1)

# for i in s1:
#     print(i, "->", s.count(i))

for i in s:
    if i not in s1:
        s1=s1+i
        print(i, "->", s.count(i))
# Out:
# a -> 5
# b -> 2
# h -> 4
# g -> 1
# s -> 2
# u -> 1
# o -> 1
# d -> 3
# k -> 5
# l -> 3
# j -> 4
# n -> 2
# c -> 2
# i -> 1
# w -> 2

# %%
s="how are you dear"

# %%
# split - convert string into list

# %%
s.split()
# Out:
# ['how', 'are', 'you', 'dear']

# %%
s="how are , you dear"

# %%
s.split(",")
# Out:
# ['how are ', ' you dear']

# %%
s="how are you dear"

# %%
s.split("e")
# Out:
# ['how ar', ' you d', 'ar']

# %%
s="my name is abhishek morya"
x=s.split()
for i in x:
    print(i)
# Out:
# my
# name
# is
# abhishek
# morya

# %%
i[0]
# Out:
# 'm'

# %%
s="abhishek"

# this is not the correct way of 
# for i in s:
#  print(i,"->", s.index(i))

# this is also not the correct way of doing this
# index=0
# for i in s:
#     print(i,index)
#     index=index+1
# Out:
# a 0
# b 1
# h 2
# i 3
# s 4
# h 5
# e 6
# k 7

# %%
s="abhishek"

for i in range(8):
    print(i, "->" , s[i])

# this is static
# Out:
# 0 -> a
# 1 -> b
# 2 -> h
# 3 -> i
# 4 -> s
# 5 -> h
# 6 -> e
# 7 -> k

# %%
# dynamic 

s="abhishek"

for i in range(len(s)):
    print(i, "->" , s[i])
# Out:
# 0 -> a
# 1 -> b
# 2 -> h
# 3 -> i
# 4 -> s
# 5 -> h
# 6 -> e
# 7 -> k

# %%
# print reverse 

s="abhishek"

# s1=""

# for i in s:
#     s1= i + s1;

# print(s1)

# using range 

for i in range(7, -1, -1):
    print(i, "->", s[i])
# Out:
# 7 -> k
# 6 -> e
# 5 -> h
# 4 -> s
# 3 -> i
# 2 -> h
# 1 -> b
# 0 -> a

# %%
# dynamic

for i in range(len(s)-1, -1, -1):
    print(i, "->", s[i])
# Out:
# 7 -> k
# 6 -> e
# 5 -> h
# 4 -> s
# 3 -> i
# 2 -> h
# 1 -> b
# 0 -> a

# %%
# write a python program to add 'ing' at the end of a string (length should be at least 3).
# if the given string aleady ends with 'ing', add 'ly' instead.
#  if the string length of the given string is less than 3, leave it unchangedabs

# sample string -> abc 
# Expected result -> 'abcing'
# sample string - > string 
# expected result -> stringly

# %%
s = "abing"

# simple indexing method

# if len(s) < 3:
#     print(s)
# elif s[-1] == 'g' and s[-2] == 'n' and s[-3] == 'i':
#     print(s +'ly')
# else:
#     print(s + 'ing')


# now with slicing


# if len(s) < 3:
#     print(s)
# elif s[-3:] == 'ing':
#     print(s + 'ly')
# else:
#     print(s + 'ing')


# using inbuilt functions

if len(s) < 3:
    print(s)
elif s.endswith('ing'):
    print(s + 'ly')
else:
    print(s + 'ing')
# Out:
# abingly

# %%
s = "abing"

if len(s) < 3:
    print(s)
elif s[-3:] == 'ing':
    print(s.replace('ing', 'ly'))
else:
    print(s + 'ing')
# Out:
# ably

# %%
# write a python function to reverse a string if its length is a multiple of 4

# %%
s = "abhimany"
s1 = ""

# if len(s) % 4 == 0:
#     for ch in s:
#         s1 = ch + s1
#     print(s1)
# else:
#     print(s)


# using slicing

if len(s) % 4 == 0:
    print(s[::-1])
else:
    print(s)
# Out:
# ynamihba

# %%
# uppercase string if 2+ uppercase chars in first 4

# %%
s = "Abhishek"
count = 0

for i in s[:4]:
    if i.isupper():
        count += 1

if count >= 2:
    print(s.upper())
else:
    print(s)
# Out:
# Abhishek

# %%
# startswith - find string/character from starting of string
# endswith - find string/character from ending of string

# %%
s="hey how are you"

s.startswith("hey")
# Out:
# True

# %%
s.endswith("ou")
# Out:
# True

# %%
# strip - remove spaces by default  and remove spaces of left and right
# lstrip - remove left side spaces
# rstrip - remove right side spaces

# %%
s = " abhishek "

# %%
s[0]
# Out:
# ' '

# %%
print(s.strip())
# Out:
# abhishek

# %%
s="**abhishek**"
s.strip("*")
# Out:
# 'abhishek'

# %%
s="**abhishek@@@"
s.strip("*").strip("@")
# Out:
# 'abhishek'

# %%
s=" abhishek "
s.lstrip()
# Out:
# 'abhishek '

# %%
s="    abhishek    "
s.rstrip()
# Out:
# '    abhishek'

# %%
s="my name is abhisek morya"
s.partition('i')


# partition('i') returns a tuple of 3 elements:

# Before the first 'i'
# The separator itself ('i')
# After the first 'i'
# Out:
# ('my name ', 'i', 's abhisek morya')

# %%
s.rpartition('i')


# rpartition() works exactly like partition(), but it splits the string at the last occurrence of the separator instead of the first.
# Out:
# ('my name is abh', 'i', 'sek morya')

# %%
s="abhishek"

s.center(20,"=")


# string.center(width, fillchar)
# width → Total length of the final string.
# fillchar → Character used to fill the empty spaces (must be a single character).
# Out:
# '======abhishek======'

# %%
# ljust
# rjust

# %%
s.ljust(20,"=")
# Out:
# 'hey how are you====='

# %%
s.rjust(20,"=")
# Out:
# '============abhishek'

# %%
s="abc"
s.zfill(15)
# Out:
# '000000000000abc'

# %%
s="abhishek"
print(s[:4:1])
# Out:
# abhi
