# %%
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('smartphone.csv')

# %%
df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
#for i in df["price"]:
 #   print(int(i.replace("₹","").replace(",","")))

# %%
# df["price"] = df["price"].str.replace("₹","").str.replace(",","").astype(int)

# %%
for i in df.index:
    df["price"][i]  =  (int(df["price"][i].replace("₹","").replace(",","")))

# %%
df["price"].mean()
# Out:
# 31371.767647058823

# %%
df.head()
# Out:
#                        model  price  rating  \
# 0              OnePlus 11 5G  54999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      Samsung Galaxy A14 5G  16499    75.0
# 3       Motorola Moto G62 5G  14999    81.0
# 4         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
df = df[df["price"]>3500]

# %%
df.head()
# Out:
#                        model  price  rating  \
# 0              OnePlus 11 5G  54999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      Samsung Galaxy A14 5G  16499    75.0
# 3       Motorola Moto G62 5G  14999    81.0
# 4         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
for i in df["processor"]:
    if 'Processor' not in i:
        print(i)
# Out:
# Bionic  A16
# Apple  A13
# Bionic A16
# No Wifi
# Snapdragon 775
# Bionic  A16
# No Wifi
# Unisoc T117
# 1450 mAh Battery
# Bionic  A16
# 32 GB inbuilt
# 1 GB RAM, 8 GB inbuilt
# No Wifi
# 256 MB RAM, 512 MB inbuilt

# %%
df[~df["processor"].str.contains("Processor")]
# Out:
#                           model   price  rating  \
# 152     Apple iPhone 15 Pro Max  142990    79.0
# 263            Apple iPhone XR2   71999    60.0
# 282        Apple iPhone 14 Mini   69990    70.0
# 376             Nokia 2660 Flip    4649     NaN
# 429                Nokia X50 5G   34999    76.0
# 448         Apple iPhone 15 Pro  130990    75.0
# 582               Nokia 8210 4G    3749     NaN
# 627                Nokia 225 4G    3589     NaN
# 645             Nokia 2760 Flip    5490     NaN
# 728             Apple iPhone 15   82990    72.0
# 754  Apple iPod Touch (7th Gen)   18900     NaN
# 857                 LG Folder 2   11999     NaN
# 882      Nokia 5710 XpressAudio    4799     NaN
# 925               Nokia 3310 4G    3999     NaN
#
#                                          sim                   processor  \
# 152  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                 Bionic  A16
# 263      Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                  Apple  A13
# 282      Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                  Bionic A16
# 376                         Dual Sim, 3G, 4G                     No Wifi
# 429     Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi              Snapdragon 775
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                 Bionic  A16
# 582                         Dual Sim, 3G, 4G                     No Wifi
# 627                  Dual Sim, 3G, 4G, VoLTE                 Unisoc T117
# 645                  Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 728      Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                 Bionic  A16
# 754                                    Wi-Fi               32 GB inbuilt
# 857                Single Sim, 3G, 4G, Wi-Fi      1 GB RAM, 8 GB inbuilt
# 882                         Dual Sim, 3G, 4G                     No Wifi
# 925           Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram  \
# 152          8 GB RAM, 256 GB inbuilt
# 263           4 GB RAM, 64 GB inbuilt
# 282          6 GB RAM, 128 GB inbuilt
# 376                       Unisoc T107
# 429           6 GB RAM, 64 GB inbuilt
# 448          8 GB RAM, 128 GB inbuilt
# 582                       Unisoc T107
# 627         64 MB RAM, 128 MB inbuilt
# 645  3.6 inches, 240 x 320 px Display
# 728          6 GB RAM, 128 GB inbuilt
# 754   4 inches, 640 x 1136 px Display
# 857                  1470 mAh Battery
# 882                       Unisoc T107
# 925                  1200 mAh Battery
#
#                                                battery  \
# 152            4352 mAh Battery with 25W Fast Charging
# 263                3060 mAh Battery with Fast Charging
# 282                3500 mAh Battery with Fast Charging
# 376                          48 MB RAM, 128 MB inbuilt
# 429            6000 mAh Battery with 33W Fast Charging
# 448  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 582                          48 MB RAM, 128 MB inbuilt
# 627                                   1150 mAh Battery
# 645                      5 MP Rear & 5 MP Front Camera
# 728                3285 mAh Battery with Fast Charging
# 754                    8 MP Rear & 1.2 MP Front Camera
# 857                   2.8 inches, 240 x 320 px Display
# 882                          48 MB RAM, 128 MB inbuilt
# 925                   2.4 inches, 240 x 320 px Display
#
#                                                display  \
# 152  6.68 inches, 1284 x 2778 px, 120 Hz Display wi...
# 263                  6.1 inches, 828 x 1792 px Display
# 282  5.42 inches, 1080 x 2340 px Display with Punch...
# 376                                   1450 mAh Battery
# 429  6.81 inches, 1080 x 2400 px Display with Punch...
# 448  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 582                                   1450 mAh Battery
# 627                   2.4 inches, 240 x 320 px Display
# 645                  Memory Card Supported, upto 32 GB
# 728  6.06 inches, 1170 x 2532 px Display with Punch...
# 754                                            iOS v12
# 857                                   2 MP Rear Camera
# 882                                   1450 mAh Battery
# 925                                   2 MP Rear Camera
#
#                                                 camera  \
# 152  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 263         12 MP + 5 MP Dual Rear & 7 MP Front Camera
# 282       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 376                   2.8 inches, 240 x 320 px Display
# 429              108 MP Quad Rear & 32 MP Front Camera
# 448                          Memory Card Not Supported
# 582                   2.8 inches, 240 x 320 px Display
# 627                                 0.3 MP Rear Camera
# 645                                         Kaios v3.0
# 728       50 MP + 13 MP Dual Rear & 13 MP Front Camera
# 754                                        No FM Radio
# 857                              Memory Card Supported
# 882                   2.4 inches, 240 x 320 px Display
# 925                  Memory Card Supported, upto 32 GB
#
#                                   card                                 os
# 152          Memory Card Not Supported                            iOS v15
# 263          Memory Card Not Supported                          iOS v12.3
# 282          Memory Card Not Supported                            iOS v15
# 376                       Dual Display                 0.3 MP Rear Camera
# 429              Memory Card Supported                        Android v11
# 448                            iOS v15                        No FM Radio
# 582                 0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 627  Memory Card Supported, upto 32 GB                  RTOS (Series 30+)
# 645                          Bluetooth                                NaN
# 728          Memory Card Not Supported                            iOS v15
# 754                          Bluetooth                            Browser
# 857                          Bluetooth                                NaN
# 882                 0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 925                          Bluetooth                            Browser

# %%
df1 = df.copy()

# %%
df1 = df1.reset_index()
df1['index'] = df1['index'] + 2

# %%
processor_rows = set((642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002))
ram_rows = set((441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002))
battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002))
display_rows = set((378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002))
camera_rows = set((100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016 ))

# %%
df1.head()
# Out:
#    index                      model  price  rating  \
# 0      2              OnePlus 11 5G  54999    89.0
# 1      3  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4      Samsung Galaxy A14 5G  16499    75.0
# 3      5       Motorola Moto G62 5G  14999    81.0
# 4      6         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
df1[df1['index'].isin(processor_rows | ram_rows | battery_rows | display_rows | camera_rows)]
# Out:
#      index                                     model   price  rating  \
# 98     100                            Vivo X Fold 5G  106990     NaN
# 111    113                           Apple iPhone 12   51999    74.0
# 149    151                      Apple iPhone 12 Mini   40999    74.0
# 155    157                           Nokia 2780 Flip    4990     NaN
# 159    161                           Oppo Find N2 5G   94990     NaN
# 235    238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 270    273                         Nokia 2720 V Flip    6199     NaN
# 305    308                   Samsung Galaxy Z Flip 3   69999    84.0
# 306    309                   Apple iPhone 12 (128GB)   55999    75.0
# 320    323                   Samsung Galaxy Z Fold 4  154998     NaN
# 321    324                          Royole FlexPai 2  109999    87.0
# 362    365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 364    367                          OPPO Find N Flip   89990    88.0
# 375    378                           Nokia 2660 Flip    4649     NaN
# 391    394                         OPPO Find N2 Flip   70990    88.0
# 437    441                    Apple iPhone SE 3 2022   43900     NaN
# 446    450                       Apple iPhone 15 Pro  130990    75.0
# 479    484                          Vivo X Fold Plus  113990     NaN
# 480    485          Huawei Mate 50 RS Porsche Design  239999    81.0
# 501    506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# 563    571                   Samsung Galaxy Z Fold 3  110999    89.0
# 564    572                                LG Wing 5G   54999    89.0
# 574    584                             Nokia 8210 4G    3749     NaN
# 603    615                              Oukitel WP21   22990    82.0
# 618    630               Apple iPhone 12 Pro (512GB)  139900    80.0
# 634    647                           Nokia 2760 Flip    5490     NaN
# 668    684                              LG V60 ThinQ   79990     NaN
# 687    705                            Oppo Find N 5G   92249     NaN
# 693    711                               OPPO X 2021  134999    86.0
# 705    723                Asus ROG Phone 6D Ultimate  107990     NaN
# 710    728                          Huawei Mate Xs 2  162990    89.0
# 737    756                Apple iPod Touch (7th Gen)   18900     NaN
# 744    764                         Apple iPhone SE 4   49990    60.0
# 772    792                        Xiaomi Mi Mix Fold  109990     NaN
# 824    846                              CAT S22 Flip   14999     NaN
# 831    855               Apple iPhone 12 Pro (256GB)  119900    80.0
# 834    858                   Samsung Galaxy A01 Core    4999     NaN
# 835    859                               LG Folder 2   11999     NaN
# 858    884                    Nokia 5710 XpressAudio    4799     NaN
# 870    896                       Royole FlexPai 3 5G  149999    87.0
# 889    915              Apple iPhone 12 Mini (256GB)   55999    75.0
# 890    916                   Apple iPhone 12 (256GB)   67999    76.0
# 900    927                             Nokia 3310 4G    3999     NaN
# 915    945  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980     NaN
# 926    956         Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 964    995                             Huawei Mate X  169000     NaN
# 984   1016                             Vivo X Fold 2  119990     NaN
#
#                                                    sim  \
# 98             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 155                            Dual Sim, 3G, 4G, Wi-Fi
# 159            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 235  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 270                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 305          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 306            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 320            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 321                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 362            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 364          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 375                                   Dual Sim, 3G, 4G
# 391          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 437            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 446            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 479            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 480    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 501            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 563            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 564            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 574                                   Dual Sim, 3G, 4G
# 603                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 618            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 634                            Dual Sim, 3G, 4G, Wi-Fi
# 668            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 687            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 693                   Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 705            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 710    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 737                                              Wi-Fi
# 744            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 772  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 824                   Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 831            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 834                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 835                          Single Sim, 3G, 4G, Wi-Fi
# 858                                   Dual Sim, 3G, 4G
# 870                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 889            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 890            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 900                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 915            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 926            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 964  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 984            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                              processor  \
# 98       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 111           Bionic A14, Hexa Core, 3.1 GHz Processor
# 149           Bionic A14, Hexa Core, 3.1 GHz Processor
# 155     Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 159   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 235  Snapdragon  8+ Gen1 , Octa Core, 3.2 GHz Proce...
# 270      Snapdragon 205 , Dual Core, 1.1 GHz Processor
# 305      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 306           Bionic A14, Hexa Core, 3.1 GHz Processor
# 320  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 321      Snapdragon 865, Octa Core, 2.84 GHz Processor
# 362           Bionic A14, Hexa Core, 3.1 GHz Processor
# 364      Dimensity 9000, Octa Core, 3.05 GHz Processor
# 375                                            No Wifi
# 391  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 437         Bionic  A15, Hexa Core, 3.22 GHz Processor
# 446                                        Bionic  A16
# 479   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 480   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 501  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 563      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 564    Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 574                                            No Wifi
# 603            Helio G99, Octa Core, 2.2 GHz Processor
# 618           Bionic A14, Hexa Core, 3.1 GHz Processor
# 634                                   1450 mAh Battery
# 668     Snapdragon  865, Octa Core, 2.84 GHz Processor
# 687     Snapdragon  888, Octa Core, 2.84 GHz Processor
# 693      Snapdragon 865, Octa Core, 2.84 GHz Processor
# 705  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 710      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 737                                      32 GB inbuilt
# 744         Bionic  A15, Hexa Core, 3.22 GHz Processor
# 772    Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 824         Qualcomm 215, Quad Core, 1.3 GHz Processor
# 831           Bionic A14, Hexa Core, 3.1 GHz Processor
# 834              (28 nm), Quad Core, 1.5 GHz Processor
# 835                             1 GB RAM, 8 GB inbuilt
# 858                                            No Wifi
# 870      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 889           Bionic A14, Hexa Core, 3.1 GHz Processor
# 890           Bionic A14, Hexa Core, 3.1 GHz Processor
# 900                         256 MB RAM, 512 MB inbuilt
# 915  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 926      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 964          Kirin  990, Octa Core, 2.86 GHz Processor
# 984    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                                   ram  \
# 98          12 GB RAM, 256 GB inbuilt
# 111           4 GB RAM, 64 GB inbuilt
# 149           4 GB RAM, 64 GB inbuilt
# 155          4 GB RAM, 512 MB inbuilt
# 159         12 GB RAM, 256 GB inbuilt
# 235         12 GB RAM, 256 GB inbuilt
# 270          512 MB RAM, 4 GB inbuilt
# 305          8 GB RAM, 128 GB inbuilt
# 306          4 GB RAM, 128 GB inbuilt
# 320         12 GB RAM, 256 GB inbuilt
# 321          8 GB RAM, 128 GB inbuilt
# 362          4 GB RAM, 128 GB inbuilt
# 364          8 GB RAM, 128 GB inbuilt
# 375                       Unisoc T107
# 391          8 GB RAM, 256 GB inbuilt
# 437                     64 GB inbuilt
# 446          8 GB RAM, 128 GB inbuilt
# 479         12 GB RAM, 256 GB inbuilt
# 480                    512 GB inbuilt
# 501          8 GB RAM, 128 GB inbuilt
# 563         12 GB RAM, 256 GB inbuilt
# 564          8 GB RAM, 128 GB inbuilt
# 574                       Unisoc T107
# 603         12 GB RAM, 256 GB inbuilt
# 618          6 GB RAM, 512 GB inbuilt
# 634  3.6 inches, 240 x 320 px Display
# 668          8 GB RAM, 128 GB inbuilt
# 687          8 GB RAM, 256 GB inbuilt
# 693          8 GB RAM, 256 GB inbuilt
# 705         16 GB RAM, 512 GB inbuilt
# 710          8 GB RAM, 512 GB inbuilt
# 737   4 inches, 640 x 1136 px Display
# 744                     64 GB inbuilt
# 772         12 GB RAM, 256 GB inbuilt
# 824           2 GB RAM, 16 GB inbuilt
# 831          6 GB RAM, 256 GB inbuilt
# 834           1 GB RAM, 16 GB inbuilt
# 835                  1470 mAh Battery
# 858                       Unisoc T107
# 870          8 GB RAM, 128 GB inbuilt
# 889          4 GB RAM, 256 GB inbuilt
# 890          4 GB RAM, 256 GB inbuilt
# 900                  1200 mAh Battery
# 915           12 GB RAM, 1 TB inbuilt
# 926         12 GB RAM, 512 GB inbuilt
# 964          8 GB RAM, 512 GB inbuilt
# 984         12 GB RAM, 256 GB inbuilt
#
#                                                battery  \
# 98             4600 mAh Battery with 66W Fast Charging
# 111  6.1 inches, 1170 x 2532 px Display with Large ...
# 149                 5.4 inches, 1080 x 2340 px Display
# 155                                   1450 mAh Battery
# 159            4520 mAh Battery with 67W Fast Charging
# 235            4500 mAh Battery with 67W Fast Charging
# 270                                   1500 mAh Battery
# 305            3300 mAh Battery with 15W Fast Charging
# 306  6.1 inches, 1170 x 2532 px Display with Large ...
# 320            4400 mAh Battery with 25W Fast Charging
# 321                                   4450 mAh Battery
# 362                 5.4 inches, 1080 x 2340 px Display
# 364            4300 mAh Battery with 44W Fast Charging
# 375                          48 MB RAM, 128 MB inbuilt
# 391            4300 mAh Battery with 44W Fast Charging
# 437                  4.7 inches, 750 x 1334 px Display
# 446  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 479            4730 mAh Battery with 80W Fast Charging
# 480            4700 mAh Battery with 66W Fast Charging
# 501            3700 mAh Battery with 25W Fast Charging
# 563            4400 mAh Battery with 25W Fast Charging
# 564                4000 mAh Battery with Fast Charging
# 574                          48 MB RAM, 128 MB inbuilt
# 603            9800 mAh Battery with 66W Fast Charging
# 618  6.1 inches, 1170 x 2532 px Display with Large ...
# 634                      5 MP Rear & 5 MP Front Camera
# 668                5000 mAh Battery with Fast Charging
# 687            4500 mAh Battery with 33W Fast Charging
# 693            4000 mAh Battery with 45W Fast Charging
# 705            6000 mAh Battery with 65W Fast Charging
# 710            4600 mAh Battery with 66W Fast Charging
# 737                    8 MP Rear & 1.2 MP Front Camera
# 744                  6.1 inches, 750 x 1580 px Display
# 772            5020 mAh Battery with 67W Fast Charging
# 824                                   2000 mAh Battery
# 831  6.1 inches, 1170 x 2532 px Display with Large ...
# 834                                   3000 mAh Battery
# 835                   2.8 inches, 240 x 320 px Display
# 858                          48 MB RAM, 128 MB inbuilt
# 870                                   3360 mAh Battery
# 889                 5.4 inches, 1080 x 2340 px Display
# 890  6.1 inches, 1170 x 2532 px Display with Large ...
# 900                   2.4 inches, 240 x 320 px Display
# 915            4400 mAh Battery with 25W Fast Charging
# 926            4600 mAh Battery with 66W Fast Charging
# 964            4500 mAh Battery with 55W Fast Charging
# 984            4800 mAh Battery with 66W Fast Charging
#
#                                                display  \
# 98         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 155                   2.7 inches, 240 x 320 px Display
# 159  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 235  8.02 inches, 1914 x 2160 px, 120 Hz Display wi...
# 270                   2.8 inches, 240 x 320 px Display
# 305  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 306       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 320  7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 321                 7.8 inches, 1440 x 1920 px Display
# 362       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 364  6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 375                                   1450 mAh Battery
# 391  6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 437                     12 MP Rear & 7 MP Front Camera
# 446  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 479  8.03 inches, 1916 x 2160 px, 120 Hz Display wi...
# 480        6.74 inches, 1212 x 2616 px, 120 Hz Display
# 501  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 563  7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 564                 6.8 inches, 1080 x 2460 px Display
# 574                                   1450 mAh Battery
# 603        6.78 inches, 1080 x 2400 px, 120 Hz Display
# 618  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 634                  Memory Card Supported, upto 32 GB
# 668  6.8 inches, 1080 x 2460 px Display with Punch ...
# 687  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 693                 7.4 inches, 1440 x 3200 px Display
# 705        6.78 inches, 1080 x 2448 px, 165 Hz Display
# 710  7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 737                                            iOS v12
# 744                  12 MP Rear & 10.8 MP Front Camera
# 772         8.01 inches, 1860 x 2480 px, 90 Hz Display
# 824                     4 inches, 480 x 640 px Display
# 831  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 834                  5.3 inches, 720 x 1480 px Display
# 835                                   2 MP Rear Camera
# 858                                   1450 mAh Battery
# 870                 7.2 inches, 1440 x 1920 px Display
# 889       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 890       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 900                                   2 MP Rear Camera
# 915  7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 926        8.03 inches, 1916 x 2160 px, 120 Hz Display
# 964                   8 inches, 2200 x 2480 px Display
# 984        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                                                 camera  \
# 98                                    Foldable Display
# 111                          Memory Card Not Supported
# 149                          Memory Card Not Supported
# 155                                       Dual Display
# 159                     Foldable Display, Dual Display
# 235                     Foldable Display, Dual Display
# 270                                       Dual Display
# 305                     Foldable Display, Dual Display
# 306                          Memory Card Not Supported
# 320                     Foldable Display, Dual Display
# 321                     Foldable Display, Dual Display
# 362                          Memory Card Not Supported
# 364                     Foldable Display, Dual Display
# 375                   2.8 inches, 240 x 320 px Display
# 391                     Foldable Display, Dual Display
# 437                          Memory Card Not Supported
# 446                          Memory Card Not Supported
# 479                     Foldable Display, Dual Display
# 480  50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 501                     Foldable Display, Dual Display
# 563                     Foldable Display, Dual Display
# 564                                       Dual Display
# 574                   2.8 inches, 240 x 320 px Display
# 603                                       Dual Display
# 618                          Memory Card Not Supported
# 634                                         Kaios v3.0
# 668                                       Dual Display
# 687                     Foldable Display, Dual Display
# 693                                       Dual Display
# 705                                       Dual Display
# 710                                   Foldable Display
# 737                                        No FM Radio
# 744                          Memory Card Not Supported
# 772                     Foldable Display, Dual Display
# 824                                       Dual Display
# 831                          Memory Card Not Supported
# 834                      8 MP Rear & 5 MP Front Camera
# 835                              Memory Card Supported
# 858                   2.4 inches, 240 x 320 px Display
# 870                     Foldable Display, Dual Display
# 889                          Memory Card Not Supported
# 890                          Memory Card Not Supported
# 900                  Memory Card Supported, upto 32 GB
# 915                     Foldable Display, Dual Display
# 926                                   Foldable Display
# 964                                   Foldable Display
# 984                                   Foldable Display
#
#                                                   card  \
# 98                50 MP Quad Rear & 16 MP Front Camera
# 111                                            iOS v14
# 149                                            iOS v14
# 155                                   5 MP Rear Camera
# 159  50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 235  50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 270                                   2 MP Rear Camera
# 305       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 306                                            iOS v14
# 320  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 321  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 362                                            iOS v14
# 364        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 375                                       Dual Display
# 391        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 437                                            iOS v15
# 446                                            iOS v15
# 479  50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 480                  Memory Card (Hybrid), upto 256 GB
# 501       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 563  12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 564  64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 574                                 0.3 MP Rear Camera
# 603  64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 618                                          iOS v14.0
# 634                                          Bluetooth
# 668  64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 687  50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# 693  64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...
# 705  50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 710  50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 737                                          Bluetooth
# 744                                            iOS v16
# 772  108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...
# 824                      5 MP Rear & 2 MP Front Camera
# 831                                          iOS v14.0
# 834                              Memory Card Supported
# 835                                          Bluetooth
# 858                                 0.3 MP Rear Camera
# 870  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 889                                            iOS v14
# 890                                            iOS v14
# 900                                          Bluetooth
# 915  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 926               50 MP Quad Rear & 16 MP Front Camera
# 964                             48 MP Quad Rear Camera
# 984  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                      os
# 98                          Android v12
# 111                         No FM Radio
# 149                         No FM Radio
# 155   Memory Card Supported, upto 32 GB
# 159           Memory Card Not Supported
# 235                         Android v12
# 270               Memory Card Supported
# 305           Memory Card Not Supported
# 306                         No FM Radio
# 320                         Android v12
# 321  Memory Card Supported, upto 256 GB
# 362                         No FM Radio
# 364           Memory Card Not Supported
# 375                  0.3 MP Rear Camera
# 391           Memory Card Not Supported
# 437                         No FM Radio
# 446                         No FM Radio
# 479                         Android v12
# 480                    Hongmeng OS v3.0
# 501           Memory Card Not Supported
# 563                         Android v11
# 564     Memory Card (Hybrid), upto 2 TB
# 574   Memory Card Supported, upto 32 GB
# 603                Memory Card (Hybrid)
# 618                         No FM Radio
# 634                                 NaN
# 668     Memory Card (Hybrid), upto 2 TB
# 687                         Android v11
# 693                         Android v11
# 705           Memory Card Not Supported
# 710   Memory Card (Hybrid), upto 256 GB
# 737                             Browser
# 744                         No FM Radio
# 772                         Android v10
# 824  Memory Card Supported, upto 128 GB
# 831                         No FM Radio
# 834                         Android v10
# 835                                 NaN
# 858   Memory Card Supported, upto 32 GB
# 870  Memory Card Supported, upto 256 GB
# 889                         No FM Radio
# 890                         No FM Radio
# 900                             Browser
# 915                         Android v12
# 926                         Android v12
# 964   Memory Card (Hybrid), upto 256 GB
# 984                         Android v12

# %%
df1[df1['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]
# Out:
#      index                   model price  rating  \
# 634    647         Nokia 2760 Flip  5490     NaN
# 858    884  Nokia 5710 XpressAudio  4799     NaN
# 900    927           Nokia 3310 4G  3999     NaN
#
#                                 sim                   processor  \
# 634         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 858                Dual Sim, 3G, 4G                     No Wifi
# 900  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 634  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 858                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 900                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                                display                             camera  \
# 634  Memory Card Supported, upto 32 GB                         Kaios v3.0
# 858                   1450 mAh Battery   2.4 inches, 240 x 320 px Display
# 900                   2 MP Rear Camera  Memory Card Supported, upto 32 GB
#
#                    card                                 os
# 634           Bluetooth                                NaN
# 858  0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 900           Bluetooth                            Browser

# %%
df1[df1['index'].isin(processor_rows)]
# Out:
#      index                   model  price  rating  \
# 634    647         Nokia 2760 Flip   5490     NaN
# 835    859             LG Folder 2  11999     NaN
# 858    884  Nokia 5710 XpressAudio   4799     NaN
# 900    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 634         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 835       Single Sim, 3G, 4G, Wi-Fi      1 GB RAM, 8 GB inbuilt
# 858                Dual Sim, 3G, 4G                     No Wifi
# 900  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 634  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 835                  1470 mAh Battery  2.8 inches, 240 x 320 px Display
# 858                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 900                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                                display                             camera  \
# 634  Memory Card Supported, upto 32 GB                         Kaios v3.0
# 835                   2 MP Rear Camera              Memory Card Supported
# 858                   1450 mAh Battery   2.4 inches, 240 x 320 px Display
# 900                   2 MP Rear Camera  Memory Card Supported, upto 32 GB
#
#                    card                                 os
# 634           Bluetooth                                NaN
# 835           Bluetooth                                NaN
# 858  0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 900           Bluetooth                            Browser

# %%
df1[df1['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 306    309       Apple iPhone 12 (128GB)   55999    75.0
# 362    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 375    378               Nokia 2660 Flip    4649     NaN
# 437    441        Apple iPhone SE 3 2022   43900     NaN
# 446    450           Apple iPhone 15 Pro  130990    75.0
# 574    584                 Nokia 8210 4G    3749     NaN
# 618    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 634    647               Nokia 2760 Flip    5490     NaN
# 737    756    Apple iPod Touch (7th Gen)   18900     NaN
# 744    764             Apple iPhone SE 4   49990    60.0
# 831    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 835    859                   LG Folder 2   11999     NaN
# 858    884        Nokia 5710 XpressAudio    4799     NaN
# 889    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 890    916       Apple iPhone 12 (256GB)   67999    76.0
# 900    927                 Nokia 3310 4G    3999     NaN
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 306  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 362  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 375                         Dual Sim, 3G, 4G
# 437  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 446  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 574                         Dual Sim, 3G, 4G
# 618  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 634                  Dual Sim, 3G, 4G, Wi-Fi
# 737                                    Wi-Fi
# 744  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 831  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 835                Single Sim, 3G, 4G, Wi-Fi
# 858                         Dual Sim, 3G, 4G
# 889  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 890  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 900           Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#                                       processor  \
# 111    Bionic A14, Hexa Core, 3.1 GHz Processor
# 149    Bionic A14, Hexa Core, 3.1 GHz Processor
# 306    Bionic A14, Hexa Core, 3.1 GHz Processor
# 362    Bionic A14, Hexa Core, 3.1 GHz Processor
# 375                                     No Wifi
# 437  Bionic  A15, Hexa Core, 3.22 GHz Processor
# 446                                 Bionic  A16
# 574                                     No Wifi
# 618    Bionic A14, Hexa Core, 3.1 GHz Processor
# 634                            1450 mAh Battery
# 737                               32 GB inbuilt
# 744  Bionic  A15, Hexa Core, 3.22 GHz Processor
# 831    Bionic A14, Hexa Core, 3.1 GHz Processor
# 835                      1 GB RAM, 8 GB inbuilt
# 858                                     No Wifi
# 889    Bionic A14, Hexa Core, 3.1 GHz Processor
# 890    Bionic A14, Hexa Core, 3.1 GHz Processor
# 900                  256 MB RAM, 512 MB inbuilt
#
#                                   ram  \
# 111           4 GB RAM, 64 GB inbuilt
# 149           4 GB RAM, 64 GB inbuilt
# 306          4 GB RAM, 128 GB inbuilt
# 362          4 GB RAM, 128 GB inbuilt
# 375                       Unisoc T107
# 437                     64 GB inbuilt
# 446          8 GB RAM, 128 GB inbuilt
# 574                       Unisoc T107
# 618          6 GB RAM, 512 GB inbuilt
# 634  3.6 inches, 240 x 320 px Display
# 737   4 inches, 640 x 1136 px Display
# 744                     64 GB inbuilt
# 831          6 GB RAM, 256 GB inbuilt
# 835                  1470 mAh Battery
# 858                       Unisoc T107
# 889          4 GB RAM, 256 GB inbuilt
# 890          4 GB RAM, 256 GB inbuilt
# 900                  1200 mAh Battery
#
#                                                battery  \
# 111  6.1 inches, 1170 x 2532 px Display with Large ...
# 149                 5.4 inches, 1080 x 2340 px Display
# 306  6.1 inches, 1170 x 2532 px Display with Large ...
# 362                 5.4 inches, 1080 x 2340 px Display
# 375                          48 MB RAM, 128 MB inbuilt
# 437                  4.7 inches, 750 x 1334 px Display
# 446  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 574                          48 MB RAM, 128 MB inbuilt
# 618  6.1 inches, 1170 x 2532 px Display with Large ...
# 634                      5 MP Rear & 5 MP Front Camera
# 737                    8 MP Rear & 1.2 MP Front Camera
# 744                  6.1 inches, 750 x 1580 px Display
# 831  6.1 inches, 1170 x 2532 px Display with Large ...
# 835                   2.8 inches, 240 x 320 px Display
# 858                          48 MB RAM, 128 MB inbuilt
# 889                 5.4 inches, 1080 x 2340 px Display
# 890  6.1 inches, 1170 x 2532 px Display with Large ...
# 900                   2.4 inches, 240 x 320 px Display
#
#                                                display  \
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 306       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 362       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 375                                   1450 mAh Battery
# 437                     12 MP Rear & 7 MP Front Camera
# 446  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 574                                   1450 mAh Battery
# 618  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 634                  Memory Card Supported, upto 32 GB
# 737                                            iOS v12
# 744                  12 MP Rear & 10.8 MP Front Camera
# 831  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 835                                   2 MP Rear Camera
# 858                                   1450 mAh Battery
# 889       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 890       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 900                                   2 MP Rear Camera
#
#                                 camera                card  \
# 111          Memory Card Not Supported             iOS v14
# 149          Memory Card Not Supported             iOS v14
# 306          Memory Card Not Supported             iOS v14
# 362          Memory Card Not Supported             iOS v14
# 375   2.8 inches, 240 x 320 px Display        Dual Display
# 437          Memory Card Not Supported             iOS v15
# 446          Memory Card Not Supported             iOS v15
# 574   2.8 inches, 240 x 320 px Display  0.3 MP Rear Camera
# 618          Memory Card Not Supported           iOS v14.0
# 634                         Kaios v3.0           Bluetooth
# 737                        No FM Radio           Bluetooth
# 744          Memory Card Not Supported             iOS v16
# 831          Memory Card Not Supported           iOS v14.0
# 835              Memory Card Supported           Bluetooth
# 858   2.4 inches, 240 x 320 px Display  0.3 MP Rear Camera
# 889          Memory Card Not Supported             iOS v14
# 890          Memory Card Not Supported             iOS v14
# 900  Memory Card Supported, upto 32 GB           Bluetooth
#
#                                     os
# 111                        No FM Radio
# 149                        No FM Radio
# 306                        No FM Radio
# 362                        No FM Radio
# 375                 0.3 MP Rear Camera
# 437                        No FM Radio
# 446                        No FM Radio
# 574  Memory Card Supported, upto 32 GB
# 618                        No FM Radio
# 634                                NaN
# 737                            Browser
# 744                        No FM Radio
# 831                        No FM Radio
# 835                                NaN
# 858  Memory Card Supported, upto 32 GB
# 889                        No FM Radio
# 890                        No FM Radio
# 900                            Browser

# %%
df1[df1['index'].isin(camera_rows)]
# Out:
#      index                                     model   price  rating  \
# 98     100                            Vivo X Fold 5G  106990     NaN
# 111    113                           Apple iPhone 12   51999    74.0
# 149    151                      Apple iPhone 12 Mini   40999    74.0
# 155    157                           Nokia 2780 Flip    4990     NaN
# 159    161                           Oppo Find N2 5G   94990     NaN
# 235    238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 270    273                         Nokia 2720 V Flip    6199     NaN
# 305    308                   Samsung Galaxy Z Flip 3   69999    84.0
# 306    309                   Apple iPhone 12 (128GB)   55999    75.0
# 320    323                   Samsung Galaxy Z Fold 4  154998     NaN
# 321    324                          Royole FlexPai 2  109999    87.0
# 362    365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 364    367                          OPPO Find N Flip   89990    88.0
# 375    378                           Nokia 2660 Flip    4649     NaN
# 391    394                         OPPO Find N2 Flip   70990    88.0
# 437    441                    Apple iPhone SE 3 2022   43900     NaN
# 446    450                       Apple iPhone 15 Pro  130990    75.0
# 479    484                          Vivo X Fold Plus  113990     NaN
# 501    506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# 563    571                   Samsung Galaxy Z Fold 3  110999    89.0
# 564    572                                LG Wing 5G   54999    89.0
# 574    584                             Nokia 8210 4G    3749     NaN
# 603    615                              Oukitel WP21   22990    82.0
# 618    630               Apple iPhone 12 Pro (512GB)  139900    80.0
# 634    647                           Nokia 2760 Flip    5490     NaN
# 668    684                              LG V60 ThinQ   79990     NaN
# 687    705                            Oppo Find N 5G   92249     NaN
# 693    711                               OPPO X 2021  134999    86.0
# 705    723                Asus ROG Phone 6D Ultimate  107990     NaN
# 710    728                          Huawei Mate Xs 2  162990    89.0
# 737    756                Apple iPod Touch (7th Gen)   18900     NaN
# 744    764                         Apple iPhone SE 4   49990    60.0
# 772    792                        Xiaomi Mi Mix Fold  109990     NaN
# 824    846                              CAT S22 Flip   14999     NaN
# 831    855               Apple iPhone 12 Pro (256GB)  119900    80.0
# 834    858                   Samsung Galaxy A01 Core    4999     NaN
# 858    884                    Nokia 5710 XpressAudio    4799     NaN
# 870    896                       Royole FlexPai 3 5G  149999    87.0
# 889    915              Apple iPhone 12 Mini (256GB)   55999    75.0
# 890    916                   Apple iPhone 12 (256GB)   67999    76.0
# 900    927                             Nokia 3310 4G    3999     NaN
# 915    945  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980     NaN
# 926    956         Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 964    995                             Huawei Mate X  169000     NaN
# 984   1016                             Vivo X Fold 2  119990     NaN
#
#                                                    sim  \
# 98             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 155                            Dual Sim, 3G, 4G, Wi-Fi
# 159            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 235  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 270                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 305          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 306            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 320            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 321                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 362            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 364          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 375                                   Dual Sim, 3G, 4G
# 391          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 437            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 446            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 479            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 501            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 563            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 564            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 574                                   Dual Sim, 3G, 4G
# 603                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 618            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 634                            Dual Sim, 3G, 4G, Wi-Fi
# 668            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 687            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 693                   Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 705            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 710    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 737                                              Wi-Fi
# 744            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 772  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 824                   Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 831            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 834                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 858                                   Dual Sim, 3G, 4G
# 870                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 889            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 890            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 900                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 915            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 926            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 964  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 984            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                              processor  \
# 98       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 111           Bionic A14, Hexa Core, 3.1 GHz Processor
# 149           Bionic A14, Hexa Core, 3.1 GHz Processor
# 155     Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 159   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 235  Snapdragon  8+ Gen1 , Octa Core, 3.2 GHz Proce...
# 270      Snapdragon 205 , Dual Core, 1.1 GHz Processor
# 305      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 306           Bionic A14, Hexa Core, 3.1 GHz Processor
# 320  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 321      Snapdragon 865, Octa Core, 2.84 GHz Processor
# 362           Bionic A14, Hexa Core, 3.1 GHz Processor
# 364      Dimensity 9000, Octa Core, 3.05 GHz Processor
# 375                                            No Wifi
# 391  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 437         Bionic  A15, Hexa Core, 3.22 GHz Processor
# 446                                        Bionic  A16
# 479   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 501  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 563      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 564    Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 574                                            No Wifi
# 603            Helio G99, Octa Core, 2.2 GHz Processor
# 618           Bionic A14, Hexa Core, 3.1 GHz Processor
# 634                                   1450 mAh Battery
# 668     Snapdragon  865, Octa Core, 2.84 GHz Processor
# 687     Snapdragon  888, Octa Core, 2.84 GHz Processor
# 693      Snapdragon 865, Octa Core, 2.84 GHz Processor
# 705  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 710      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 737                                      32 GB inbuilt
# 744         Bionic  A15, Hexa Core, 3.22 GHz Processor
# 772    Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 824         Qualcomm 215, Quad Core, 1.3 GHz Processor
# 831           Bionic A14, Hexa Core, 3.1 GHz Processor
# 834              (28 nm), Quad Core, 1.5 GHz Processor
# 858                                            No Wifi
# 870      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 889           Bionic A14, Hexa Core, 3.1 GHz Processor
# 890           Bionic A14, Hexa Core, 3.1 GHz Processor
# 900                         256 MB RAM, 512 MB inbuilt
# 915  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 926      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 964          Kirin  990, Octa Core, 2.86 GHz Processor
# 984    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                                   ram  \
# 98          12 GB RAM, 256 GB inbuilt
# 111           4 GB RAM, 64 GB inbuilt
# 149           4 GB RAM, 64 GB inbuilt
# 155          4 GB RAM, 512 MB inbuilt
# 159         12 GB RAM, 256 GB inbuilt
# 235         12 GB RAM, 256 GB inbuilt
# 270          512 MB RAM, 4 GB inbuilt
# 305          8 GB RAM, 128 GB inbuilt
# 306          4 GB RAM, 128 GB inbuilt
# 320         12 GB RAM, 256 GB inbuilt
# 321          8 GB RAM, 128 GB inbuilt
# 362          4 GB RAM, 128 GB inbuilt
# 364          8 GB RAM, 128 GB inbuilt
# 375                       Unisoc T107
# 391          8 GB RAM, 256 GB inbuilt
# 437                     64 GB inbuilt
# 446          8 GB RAM, 128 GB inbuilt
# 479         12 GB RAM, 256 GB inbuilt
# 501          8 GB RAM, 128 GB inbuilt
# 563         12 GB RAM, 256 GB inbuilt
# 564          8 GB RAM, 128 GB inbuilt
# 574                       Unisoc T107
# 603         12 GB RAM, 256 GB inbuilt
# 618          6 GB RAM, 512 GB inbuilt
# 634  3.6 inches, 240 x 320 px Display
# 668          8 GB RAM, 128 GB inbuilt
# 687          8 GB RAM, 256 GB inbuilt
# 693          8 GB RAM, 256 GB inbuilt
# 705         16 GB RAM, 512 GB inbuilt
# 710          8 GB RAM, 512 GB inbuilt
# 737   4 inches, 640 x 1136 px Display
# 744                     64 GB inbuilt
# 772         12 GB RAM, 256 GB inbuilt
# 824           2 GB RAM, 16 GB inbuilt
# 831          6 GB RAM, 256 GB inbuilt
# 834           1 GB RAM, 16 GB inbuilt
# 858                       Unisoc T107
# 870          8 GB RAM, 128 GB inbuilt
# 889          4 GB RAM, 256 GB inbuilt
# 890          4 GB RAM, 256 GB inbuilt
# 900                  1200 mAh Battery
# 915           12 GB RAM, 1 TB inbuilt
# 926         12 GB RAM, 512 GB inbuilt
# 964          8 GB RAM, 512 GB inbuilt
# 984         12 GB RAM, 256 GB inbuilt
#
#                                                battery  \
# 98             4600 mAh Battery with 66W Fast Charging
# 111  6.1 inches, 1170 x 2532 px Display with Large ...
# 149                 5.4 inches, 1080 x 2340 px Display
# 155                                   1450 mAh Battery
# 159            4520 mAh Battery with 67W Fast Charging
# 235            4500 mAh Battery with 67W Fast Charging
# 270                                   1500 mAh Battery
# 305            3300 mAh Battery with 15W Fast Charging
# 306  6.1 inches, 1170 x 2532 px Display with Large ...
# 320            4400 mAh Battery with 25W Fast Charging
# 321                                   4450 mAh Battery
# 362                 5.4 inches, 1080 x 2340 px Display
# 364            4300 mAh Battery with 44W Fast Charging
# 375                          48 MB RAM, 128 MB inbuilt
# 391            4300 mAh Battery with 44W Fast Charging
# 437                  4.7 inches, 750 x 1334 px Display
# 446  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 479            4730 mAh Battery with 80W Fast Charging
# 501            3700 mAh Battery with 25W Fast Charging
# 563            4400 mAh Battery with 25W Fast Charging
# 564                4000 mAh Battery with Fast Charging
# 574                          48 MB RAM, 128 MB inbuilt
# 603            9800 mAh Battery with 66W Fast Charging
# 618  6.1 inches, 1170 x 2532 px Display with Large ...
# 634                      5 MP Rear & 5 MP Front Camera
# 668                5000 mAh Battery with Fast Charging
# 687            4500 mAh Battery with 33W Fast Charging
# 693            4000 mAh Battery with 45W Fast Charging
# 705            6000 mAh Battery with 65W Fast Charging
# 710            4600 mAh Battery with 66W Fast Charging
# 737                    8 MP Rear & 1.2 MP Front Camera
# 744                  6.1 inches, 750 x 1580 px Display
# 772            5020 mAh Battery with 67W Fast Charging
# 824                                   2000 mAh Battery
# 831  6.1 inches, 1170 x 2532 px Display with Large ...
# 834                                   3000 mAh Battery
# 858                          48 MB RAM, 128 MB inbuilt
# 870                                   3360 mAh Battery
# 889                 5.4 inches, 1080 x 2340 px Display
# 890  6.1 inches, 1170 x 2532 px Display with Large ...
# 900                   2.4 inches, 240 x 320 px Display
# 915            4400 mAh Battery with 25W Fast Charging
# 926            4600 mAh Battery with 66W Fast Charging
# 964            4500 mAh Battery with 55W Fast Charging
# 984            4800 mAh Battery with 66W Fast Charging
#
#                                                display  \
# 98         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 155                   2.7 inches, 240 x 320 px Display
# 159  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 235  8.02 inches, 1914 x 2160 px, 120 Hz Display wi...
# 270                   2.8 inches, 240 x 320 px Display
# 305  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 306       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 320  7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 321                 7.8 inches, 1440 x 1920 px Display
# 362       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 364  6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 375                                   1450 mAh Battery
# 391  6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 437                     12 MP Rear & 7 MP Front Camera
# 446  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 479  8.03 inches, 1916 x 2160 px, 120 Hz Display wi...
# 501  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 563  7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 564                 6.8 inches, 1080 x 2460 px Display
# 574                                   1450 mAh Battery
# 603        6.78 inches, 1080 x 2400 px, 120 Hz Display
# 618  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 634                  Memory Card Supported, upto 32 GB
# 668  6.8 inches, 1080 x 2460 px Display with Punch ...
# 687  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 693                 7.4 inches, 1440 x 3200 px Display
# 705        6.78 inches, 1080 x 2448 px, 165 Hz Display
# 710  7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 737                                            iOS v12
# 744                  12 MP Rear & 10.8 MP Front Camera
# 772         8.01 inches, 1860 x 2480 px, 90 Hz Display
# 824                     4 inches, 480 x 640 px Display
# 831  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 834                  5.3 inches, 720 x 1480 px Display
# 858                                   1450 mAh Battery
# 870                 7.2 inches, 1440 x 1920 px Display
# 889       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 890       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 900                                   2 MP Rear Camera
# 915  7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 926        8.03 inches, 1916 x 2160 px, 120 Hz Display
# 964                   8 inches, 2200 x 2480 px Display
# 984        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                                 camera  \
# 98                    Foldable Display
# 111          Memory Card Not Supported
# 149          Memory Card Not Supported
# 155                       Dual Display
# 159     Foldable Display, Dual Display
# 235     Foldable Display, Dual Display
# 270                       Dual Display
# 305     Foldable Display, Dual Display
# 306          Memory Card Not Supported
# 320     Foldable Display, Dual Display
# 321     Foldable Display, Dual Display
# 362          Memory Card Not Supported
# 364     Foldable Display, Dual Display
# 375   2.8 inches, 240 x 320 px Display
# 391     Foldable Display, Dual Display
# 437          Memory Card Not Supported
# 446          Memory Card Not Supported
# 479     Foldable Display, Dual Display
# 501     Foldable Display, Dual Display
# 563     Foldable Display, Dual Display
# 564                       Dual Display
# 574   2.8 inches, 240 x 320 px Display
# 603                       Dual Display
# 618          Memory Card Not Supported
# 634                         Kaios v3.0
# 668                       Dual Display
# 687     Foldable Display, Dual Display
# 693                       Dual Display
# 705                       Dual Display
# 710                   Foldable Display
# 737                        No FM Radio
# 744          Memory Card Not Supported
# 772     Foldable Display, Dual Display
# 824                       Dual Display
# 831          Memory Card Not Supported
# 834      8 MP Rear & 5 MP Front Camera
# 858   2.4 inches, 240 x 320 px Display
# 870     Foldable Display, Dual Display
# 889          Memory Card Not Supported
# 890          Memory Card Not Supported
# 900  Memory Card Supported, upto 32 GB
# 915     Foldable Display, Dual Display
# 926                   Foldable Display
# 964                   Foldable Display
# 984                   Foldable Display
#
#                                                   card  \
# 98                50 MP Quad Rear & 16 MP Front Camera
# 111                                            iOS v14
# 149                                            iOS v14
# 155                                   5 MP Rear Camera
# 159  50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 235  50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 270                                   2 MP Rear Camera
# 305       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 306                                            iOS v14
# 320  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 321  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 362                                            iOS v14
# 364        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 375                                       Dual Display
# 391        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 437                                            iOS v15
# 446                                            iOS v15
# 479  50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 501       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 563  12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 564  64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 574                                 0.3 MP Rear Camera
# 603  64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 618                                          iOS v14.0
# 634                                          Bluetooth
# 668  64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 687  50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# 693  64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...
# 705  50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 710  50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 737                                          Bluetooth
# 744                                            iOS v16
# 772  108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...
# 824                      5 MP Rear & 2 MP Front Camera
# 831                                          iOS v14.0
# 834                              Memory Card Supported
# 858                                 0.3 MP Rear Camera
# 870  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 889                                            iOS v14
# 890                                            iOS v14
# 900                                          Bluetooth
# 915  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 926               50 MP Quad Rear & 16 MP Front Camera
# 964                             48 MP Quad Rear Camera
# 984  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                      os
# 98                          Android v12
# 111                         No FM Radio
# 149                         No FM Radio
# 155   Memory Card Supported, upto 32 GB
# 159           Memory Card Not Supported
# 235                         Android v12
# 270               Memory Card Supported
# 305           Memory Card Not Supported
# 306                         No FM Radio
# 320                         Android v12
# 321  Memory Card Supported, upto 256 GB
# 362                         No FM Radio
# 364           Memory Card Not Supported
# 375                  0.3 MP Rear Camera
# 391           Memory Card Not Supported
# 437                         No FM Radio
# 446                         No FM Radio
# 479                         Android v12
# 501           Memory Card Not Supported
# 563                         Android v11
# 564     Memory Card (Hybrid), upto 2 TB
# 574   Memory Card Supported, upto 32 GB
# 603                Memory Card (Hybrid)
# 618                         No FM Radio
# 634                                 NaN
# 668     Memory Card (Hybrid), upto 2 TB
# 687                         Android v11
# 693                         Android v11
# 705           Memory Card Not Supported
# 710   Memory Card (Hybrid), upto 256 GB
# 737                             Browser
# 744                         No FM Radio
# 772                         Android v10
# 824  Memory Card Supported, upto 128 GB
# 831                         No FM Radio
# 834                         Android v10
# 858   Memory Card Supported, upto 32 GB
# 870  Memory Card Supported, upto 256 GB
# 889                         No FM Radio
# 890                         No FM Radio
# 900                             Browser
# 915                         Android v12
# 926                         Android v12
# 964   Memory Card (Hybrid), upto 256 GB
# 984                         Android v12
